# %%
# %autoreload 2

# %%
from argparse import Namespace
from collections import defaultdict, OrderedDict
import copy
import dataclasses
import gzip
import itertools
import os
import pickle
import sys
import time
import typing
import re

from IPython.display import display, Markdown, Latex
import numpy as np
import tqdm.notebook as tqdm

sys.path.append(os.path.abspath('..'))
sys.path.append(os.path.abspath('../src'))
from src.ast_utils import load_games_from_file, _extract_game_id
from ast_counter_sampler import *

# %%
RANDOM_SEED = 33
PRIOR_COUNT = 12

args = Namespace(
    parse_counter=False, 
    counter_output_path=os.path.join('..', DEFAULT_COUNTER_OUTPUT_PATH),
    grammar_file=os.path.join('..', DEFAULT_GRAMMAR_FILE),
    random_seed=RANDOM_SEED,
    test_files=['../dsl/interactive-beta.pddl'],
    dont_tqdm=False,
)

grammar = open(args.grammar_file).read()
grammar_parser = tatsu.compile(grammar)
counter = parse_or_load_counter(args, grammar_parser)

length_prior = {n: PRIOR_COUNT for n in LENGTH_PRIOR}
sampler = ASTSampler(grammar_parser, counter, seed=args.random_seed,
                     prior_rule_count=PRIOR_COUNT, prior_token_count=PRIOR_COUNT,
                     length_prior=length_prior)

PATTERN_RULES = {k: re.compile(v['pattern']) for k, v in sampler.rules.items() if 'pattern' in v}
PATTERN_RULES['predicate_name'] = PATTERN_RULES['name']
PATTERN_RULES['type_name'] = PATTERN_RULES['name']
PATTERN_RULES['location'] = PATTERN_RULES['name']

# %%
EXPANSION_STRING = '&rarr;'


@dataclasses.dataclass
class Expansion:
    rule: str
    expansions: typing.List[str] = dataclasses.field(default_factory=list)
    probability: float = 1.0
    expansion_string: str = EXPANSION_STRING

    def __str__(self):
        return f'{self.rule.upper()} {self.expansion_string} {" ".join(self.expansions)}    (P = {self.probability:.4f})'


def _add_to_expansions(expansions: typing.List[Expansion], addition: str, probability=None):
    for expansion in expansions:
        expansion.expansions.append(addition)

        if probability is not None:
            expansion.probability *= probability
    
    return expansions


def _multiple_add_to_components(expansions: typing.List[Expansion], additions_to_probabilities: typing.Dict[str, float]):
    if len(additions_to_probabilities) == 1:
        key = next(iter(additions_to_probabilities))
        return _add_to_expansions(expansions, key.upper(), additions_to_probabilities[key])

    original_length = len(expansions)
    temp = [copy.deepcopy(expansions) for _ in range(len(additions_to_probabilities))]
    expansions = [comp for component in temp for comp in component]

    for i, (addition, probability) in enumerate(additions_to_probabilities.items()):
        for j in range(original_length):
            current = expansions[i * original_length + j]
            current.expansions.append(addition.upper())
            if probability is not None:
                current.probability *= probability

    return expansions


def print_rule_cfg(rule: str, rules: typing.Dict[str, typing.Dict[str, typing.Any]],
    pattern_rules: typing.Dict[str, re.Pattern] = PATTERN_RULES, 
    expansion_string: str = EXPANSION_STRING
    ):

    if rule not in rules or rule == 'empty_closure':
        return [], [], {}

    rule_dict = rules[rule]

    if PRODUCTION not in rule_dict:
        raise ValueError(f'No production for {rule}')

    expansions = [Expansion(rule, expansion_string=expansion_string)]
    encountered_rules = []
    encountered_tokens = defaultdict(dict)

    for prod_type, prod_value in rule_dict[PRODUCTION]:
        if prod_type == RULE:
            expansions = _add_to_expansions(expansions, prod_value.upper())
            encountered_rules.append(prod_value)

        elif prod_type == TOKEN:
            if prod_value == SAMPLE:
                expansions = _multiple_add_to_components(expansions, rule_dict[TOKEN_POSTERIOR])

            elif prod_value != EOF:
                expansions = _add_to_expansions(expansions, prod_value)

        elif prod_type == NAMED:
            if prod_value not in rule_dict:
                raise ValueError(f'Unknown named {prod_value}')

            named_dict = rule_dict[prod_value]
            options = named_dict[OPTIONS]

            # Handle the rules that have a single named option that expands to a terminal
            if (rule, prod_value) in SPECIAL_RULE_FIELD_VALUE_TYPES:
                print(f'Found special rule {rule} {prod_value}')
                for t, p in named_dict[TOKEN_POSTERIOR].items():
                    encountered_tokens[rule][t] = p

                expansions = _add_to_expansions(expansions, '<TOKEN> (see below)')
            
            else:
                if isinstance(options, str):
                    out = options.upper()
                    if MIN_LENGTH in named_dict:
                        min_length = named_dict[MIN_LENGTH]
                        out = f'[ {out} ]{"*" if min_length == 0 else "+"}'

                    expansions = _add_to_expansions(expansions, out)
                    encountered_rules.append(options)
                    options = [options]

                else:
                    # if MIN_LENGTH in named_dict:
                        # continue
                        # raise ValueError(f'Min length not supported for multiple options {prod_value}')
                    expansions = _multiple_add_to_components(expansions, 
                        {opt: (named_dict[RULE_POSTERIOR][opt] if (RULE_POSTERIOR in named_dict and opt in named_dict[RULE_POSTERIOR]) else None) 
                        for opt in options}  # type: ignore
                    )
                    encountered_rules.extend(options)

                if TOKEN_POSTERIOR in named_dict:
                    for t, p in named_dict[TOKEN_POSTERIOR].items():
                        if t in rules: continue

                        if len(options) == 1:
                            encountered_tokens[options[0]][t] = p
                            continue

                        if isinstance(t, (int, float)):
                            encountered_tokens['number'][t] = p
                            continue

                        for opt in options:
                            if opt in pattern_rules and pattern_rules[opt].match(t):
                                encountered_tokens[opt][t] = p
                                break

        elif prod_type == PATTERN:
            expansions = _add_to_expansions(expansions, f'/{prod_value}/')

        else:
            raise ValueError(f'Unknown production type {prod_type}')

    if PRODUCTION_PROBABILITY in rule_dict:
        production_probability = rule_dict[PRODUCTION_PROBABILITY]
        for expansion in expansions:
            expansion.probability *= production_probability

        expansions.append(Expansion(rule, ['$\\epsilon$'], probability=1 - production_probability, expansion_string=expansion_string))

    sum_probs = sum(exp.probability for exp in expansions)
    for exp in expansions:
        exp.probability /= sum_probs

    return [str(exp) for exp in expansions], encountered_rules, encountered_tokens


def extract_cfg_rule_dict(rules: typing.Dict[str, typing.Dict[str, typing.Any]], start_rule: str = START, expansion_string: str = EXPANSION_STRING):
    rule_frontier = [start_rule]
    encountered_rules = set(rule_frontier)
    
    cfg_expansions_by_rule = OrderedDict()
    token_rule_expansions = defaultdict(dict)

    while rule_frontier:
        rule = rule_frontier.pop()
        cfg_expansions, new_rules, new_tokens = print_rule_cfg(rule, rules, expansion_string=expansion_string)
        cfg_expansions_by_rule[rule] = cfg_expansions

        for new_rule in reversed(new_rules):
            if new_rule not in encountered_rules:
                rule_frontier.append(new_rule)
                encountered_rules.add(new_rule)

        for rule, tokens in new_tokens.items():
            token_rule_expansions[rule].update(tokens)

    cfg_expansions_by_rule['token_rules'] = ['## Token rule expansions']
    for rule, tokens in token_rule_expansions.items():
        cfg_expansions_by_rule[rule] = [f'{rule.upper()} {expansion_string} {token}    (P = {prob:.4f})' for token, prob in tokens.items()]

    return cfg_expansions_by_rule


def print_rules_cfg(rules: typing.Dict[str, typing.Dict[str, typing.Any]], start_rule: str = START, expansion_string: str = EXPANSION_STRING):
    cfg_expansions_by_rule = extract_cfg_rule_dict(rules, start_rule, expansion_string=expansion_string)
    return '\n'.join(itertools.chain.from_iterable(cfg_expansions_by_rule[rule] for rule in cfg_expansions_by_rule))


cfg_expansions_by_rule = extract_cfg_rule_dict(sampler.rules, expansion_string='=>')
markdown_output = print_rules_cfg(sampler.rules, expansion_string='=>')
# Out:
# Found special rule object_type terminal
# Found special rule color_type terminal
# Found special rule color terminal
# Found special rule orientation_type terminal
# Found special rule orientation terminal
# Found special rule side_type terminal
# Found special rule side terminal
# Found special rule predicate_or_function_term term
# Found special rule predicate_or_function_side_term term
# Found special rule predicate_or_function_orientation_term term
# Found special rule predicate_or_function_color_term term
# Found special rule predicate_or_function_type_term term
# Found special rule object_name terminal
# Found special rule object_type terminal
# Found special rule color_type terminal
# Found special rule color terminal
# Found special rule orientation_type terminal
# Found special rule orientation terminal
# Found special rule side_type terminal
# Found special rule side terminal
# Found special rule predicate_or_function_term term
# Found special rule predicate_or_function_side_term term
# Found special rule predicate_or_function_orientation_term term
# Found special rule predicate_or_function_color_term term
# Found special rule predicate_or_function_type_term term
# Found special rule object_name terminal

# %%
SECTION_TEMPLATE = """
\\subsection{{{title}}}
{prefix_text}

\\begin{{lstlisting}}
{rules_text}
\\end{{lstlisting}}

{suffix_text}

""".strip()


@dataclasses.dataclass
class PCFGSectionDefinition:
    title: str
    rules: typing.List[str]
    rule_comments: typing.Dict[str, str] = dataclasses.field(default_factory=dict)
    prefix_text: str = ''
    suffix_text: str = ''

    def format(self, rule_expansions: typing.Dict[str, typing.List[typing.Union[Expansion, str]]]):
        rule_texts = []
        for rule in self.rules:
            if rule not in rule_expansions:
                raise ValueError(f'Unknown rule {rule}')
            
            expansions = [str(exp) for exp in rule_expansions[rule]]

            if rule in self.rule_comments:
                expansions.insert(0, f'# {self.rule_comments[rule]}')

            rule_texts.append('\n'.join(expansions))

        rules_text = '\n'.join(rule_texts)
        return SECTION_TEMPLATE.format(title=self.title, prefix_text=self.prefix_text, rules_text=rules_text, suffix_text=self.suffix_text)




PCFG_SECTIONS = [
    PCFGSectionDefinition('Overall Game Definition', ['start', 'game_def', 'domain_def', 'id'],
                          dict(id='An ID is a string of letters, numbers, and dashes that starts with a letter or number.')),
]


for pcfg_section in PCFG_SECTIONS:
    print(pcfg_section.format(cfg_expansions_by_rule))
# Out:
# \subsection{Overall Game Definition}
#
#
# \begin{lstlisting}
# START => (define GAME_DEF DOMAIN_DEF SETUP_DEF CONSTRAINTS_DEF TERMINAL_DEF SCORING_DEF )    (P = 1.0000)
# GAME_DEF => (game ID )    (P = 1.0000)
# DOMAIN_DEF => (:domain ID )    (P = 1.0000)
# # An ID is a string of letters, numbers, and dashes that starts with a letter or number.
# ID => /[a-z0-9][a-z0-9\-]+/    (P = 1.0000)
# \end{lstlisting}

# %%
print(markdown_output)
# Out:
# START => (define GAME_DEF DOMAIN_DEF SETUP_DEF CONSTRAINTS_DEF TERMINAL_DEF SCORING_DEF )    (P = 1.0000)
# GAME_DEF => (game ID )    (P = 1.0000)
# ID => /[a-z0-9][a-z0-9\-]+/    (P = 1.0000)
# DOMAIN_DEF => (:domain ID )    (P = 1.0000)
# SETUP_DEF => (:setup SETUP )    (P = 0.6020)
# SETUP_DEF => $\epsilon$    (P = 0.3980)
# SETUP => SETUP_AND    (P = 0.2322)
# SETUP => SETUP_OR    (P = 0.0372)
# SETUP => SETUP_NOT    (P = 0.0372)
# SETUP => SETUP_EXISTS    (P = 0.2074)
# SETUP => SETUP_FORALL    (P = 0.1455)
# SETUP => SETUP_STATEMENT    (P = 0.3406)
# SETUP_AND => (and [ SETUP ]+ )    (P = 1.0000)
# SETUP_OR => (or [ SETUP ]+ )    (P = 1.0000)
# SETUP_NOT => (not SETUP )    (P = 1.0000)
# SETUP_EXISTS => (exists VARIABLE_LIST SETUP )    (P = 1.0000)
# VARIABLE_LIST => ( VARIABLE_TYPE_DEF )    (P = 0.9252)
# VARIABLE_LIST => ( COLOR_VARIABLE_TYPE_DEF )    (P = 0.0340)
# VARIABLE_LIST => ( ORIENTATION_VARIABLE_TYPE_DEF )    (P = 0.0204)
# VARIABLE_LIST => ( SIDE_VARIABLE_TYPE_DEF )    (P = 0.0204)
# VARIABLE_TYPE_DEF => [ VARIABLE ]+ - TYPE_DEFINITION    (P = 1.0000)
# VARIABLE => /\?[a-w][a-z0-9]*/    (P = 1.0000)
# TYPE_DEFINITION => OBJECT_TYPE    (P = 0.8687)
# TYPE_DEFINITION => EITHER_TYPES    (P = 0.1313)
# OBJECT_TYPE => desk    (P = 0.0063)
# OBJECT_TYPE => cellphone    (P = 0.0095)
# OBJECT_TYPE => triangle_block_green    (P = 0.0063)
# OBJECT_TYPE => dodgeball_blue    (P = 0.0095)
# OBJECT_TYPE => watch    (P = 0.0074)
# OBJECT_TYPE => flat_block_gray    (P = 0.0063)
# OBJECT_TYPE => beachball    (P = 0.0184)
# OBJECT_TYPE => triangular_ramp_tan    (P = 0.0063)
# OBJECT_TYPE => mug    (P = 0.0079)
# OBJECT_TYPE => pencil    (P = 0.0074)
# OBJECT_TYPE => cube_block_yellow    (P = 0.0105)
# OBJECT_TYPE => dodgeball_red    (P = 0.0084)
# OBJECT_TYPE => bridge_block_green    (P = 0.0063)
# OBJECT_TYPE => drawer    (P = 0.0090)
# OBJECT_TYPE => dodgeball    (P = 0.0632)
# OBJECT_TYPE => tall_rectangular_block_green    (P = 0.0063)
# OBJECT_TYPE => ball    (P = 0.0274)
# OBJECT_TYPE => flat_block_tan    (P = 0.0063)
# OBJECT_TYPE => chair    (P = 0.0158)
# OBJECT_TYPE => golfball_white    (P = 0.0063)
# OBJECT_TYPE => tall_cylindrical_block    (P = 0.0100)
# OBJECT_TYPE => block    (P = 0.0211)
# OBJECT_TYPE => pyramid_block_blue    (P = 0.0079)
# OBJECT_TYPE => bridge_block    (P = 0.0121)
# OBJECT_TYPE => blinds    (P = 0.0074)
# OBJECT_TYPE => cube_block_tan    (P = 0.0068)
# OBJECT_TYPE => top_drawer    (P = 0.0068)
# OBJECT_TYPE => tall_cylindrical_block_green    (P = 0.0063)
# OBJECT_TYPE => key_chain    (P = 0.0090)
# OBJECT_TYPE => triangular_ramp    (P = 0.0116)
# OBJECT_TYPE => east_sliding_door    (P = 0.0063)
# OBJECT_TYPE => tall_cylindrical_block_yellow    (P = 0.0063)
# OBJECT_TYPE => pyramid_block    (P = 0.0132)
# OBJECT_TYPE => dodgeball_pink    (P = 0.0105)
# OBJECT_TYPE => pyramid_block_red    (P = 0.0074)
# OBJECT_TYPE => mirror    (P = 0.0063)
# OBJECT_TYPE => poster    (P = 0.0063)
# OBJECT_TYPE => alarm_clock    (P = 0.0105)
# OBJECT_TYPE => cylindrical_block_green    (P = 0.0063)
# OBJECT_TYPE => bed    (P = 0.0068)
# OBJECT_TYPE => tall_rectangular_block    (P = 0.0063)
# OBJECT_TYPE => building    (P = 0.0169)
# OBJECT_TYPE => book    (P = 0.0121)
# OBJECT_TYPE => cylindrical_block_tan    (P = 0.0063)
# OBJECT_TYPE => triangle_block_blue    (P = 0.0063)
# OBJECT_TYPE => cd    (P = 0.0095)
# OBJECT_TYPE => flat_block_yellow    (P = 0.0063)
# OBJECT_TYPE => ramp    (P = 0.0063)
# OBJECT_TYPE => triangular_ramp_green    (P = 0.0068)
# OBJECT_TYPE => doggie_bed    (P = 0.0200)
# OBJECT_TYPE => door    (P = 0.0063)
# OBJECT_TYPE => tall_cylindrical_block_tan    (P = 0.0063)
# OBJECT_TYPE => floor    (P = 0.0074)
# OBJECT_TYPE => curved_wooden_ramp    (P = 0.0153)
# OBJECT_TYPE => cylindrical_block    (P = 0.0121)
# OBJECT_TYPE => golfball_orange    (P = 0.0063)
# OBJECT_TYPE => north_wall    (P = 0.0063)
# OBJECT_TYPE => tall_rectangular_block_blue    (P = 0.0063)
# OBJECT_TYPE => room_center    (P = 0.0063)
# OBJECT_TYPE => wall    (P = 0.0153)
# OBJECT_TYPE => golfball_green    (P = 0.0079)
# OBJECT_TYPE => top_shelf    (P = 0.0063)
# OBJECT_TYPE => sliding_door    (P = 0.0074)
# OBJECT_TYPE => west_wall    (P = 0.0063)
# OBJECT_TYPE => east_wall    (P = 0.0063)
# OBJECT_TYPE => bridge_block_pink    (P = 0.0063)
# OBJECT_TYPE => tall_rectangular_block_tan    (P = 0.0063)
# OBJECT_TYPE => rug    (P = 0.0068)
# OBJECT_TYPE => desktop    (P = 0.0095)
# OBJECT_TYPE => bridge_block_tan    (P = 0.0063)
# OBJECT_TYPE => shelf    (P = 0.0116)
# OBJECT_TYPE => south_wall    (P = 0.0063)
# OBJECT_TYPE => west_sliding_door    (P = 0.0063)
# OBJECT_TYPE => laptop    (P = 0.0100)
# OBJECT_TYPE => pillow    (P = 0.0137)
# OBJECT_TYPE => pyramid_block_yellow    (P = 0.0074)
# OBJECT_TYPE => triangle_block_tan    (P = 0.0063)
# OBJECT_TYPE => credit_card    (P = 0.0068)
# OBJECT_TYPE => bottom_shelf    (P = 0.0063)
# OBJECT_TYPE => hexagonal_bin    (P = 0.0711)
# OBJECT_TYPE => flat_block    (P = 0.0090)
# OBJECT_TYPE => lamp    (P = 0.0074)
# OBJECT_TYPE => cube_block    (P = 0.0263)
# OBJECT_TYPE => pen    (P = 0.0074)
# OBJECT_TYPE => game_object    (P = 0.0237)
# OBJECT_TYPE => shelf_desk    (P = 0.0074)
# OBJECT_TYPE => teddy_bear    (P = 0.0137)
# OBJECT_TYPE => triangle_block    (P = 0.0079)
# OBJECT_TYPE => golfball    (P = 0.0195)
# OBJECT_TYPE => main_light_switch    (P = 0.0074)
# OBJECT_TYPE => cylindrical_block_blue    (P = 0.0063)
# OBJECT_TYPE => bottom_drawer    (P = 0.0063)
# OBJECT_TYPE => cube_block_blue    (P = 0.0105)
# OBJECT_TYPE => basketball    (P = 0.0158)
# OBJECT_TYPE => side_table    (P = 0.0068)
# EITHER_TYPES => (either [ OBJECT_TYPE ]+ )    (P = 1.0000)
# COLOR_VARIABLE_TYPE_DEF => [ COLOR_VARIABLE ]+ - COLOR_TYPE_DEFINITION    (P = 1.0000)
# COLOR_VARIABLE => /\?x[0-9]*/    (P = 1.0000)
# COLOR_TYPE_DEFINITION => COLOR_TYPE    (P = 0.5625)
# COLOR_TYPE_DEFINITION => EITHER_COLOR_TYPES    (P = 0.4375)
# COLOR_TYPE => color    (P = 1.0000)
# EITHER_COLOR_TYPES => (either [ COLOR ]+ )    (P = 1.0000)
# COLOR => blue    (P = 0.0891)
# COLOR => brown    (P = 0.0842)
# COLOR => gray    (P = 0.0594)
# COLOR => green    (P = 0.0990)
# COLOR => orange    (P = 0.0743)
# COLOR => pink    (P = 0.1535)
# COLOR => purple    (P = 0.0792)
# COLOR => red    (P = 0.0990)
# COLOR => tan    (P = 0.0693)
# COLOR => white    (P = 0.0644)
# COLOR => yellow    (P = 0.1287)
# ORIENTATION_VARIABLE_TYPE_DEF => [ ORIENTATION_VARIABLE ]+ - ORIENTATION_TYPE_DEFINITION    (P = 1.0000)
# ORIENTATION_VARIABLE => /\?y[0-9]*/    (P = 1.0000)
# ORIENTATION_TYPE_DEFINITION => ORIENTATION_TYPE    (P = 0.5000)
# ORIENTATION_TYPE_DEFINITION => EITHER_ORIENTATION_TYPES    (P = 0.5000)
# ORIENTATION_TYPE => orientation    (P = 1.0000)
# EITHER_ORIENTATION_TYPES => (either [ ORIENTATION ]+ )    (P = 1.0000)
# ORIENTATION => diagonal    (P = 0.2097)
# ORIENTATION => sideways    (P = 0.2258)
# ORIENTATION => upright    (P = 0.3548)
# ORIENTATION => upside_down    (P = 0.2097)
# SIDE_VARIABLE_TYPE_DEF => [ SIDE_VARIABLE ]+ - SIDE_TYPE_DEFINITION    (P = 1.0000)
# SIDE_VARIABLE => /\?z[0-9]*/    (P = 1.0000)
# SIDE_TYPE_DEFINITION => SIDE_TYPE    (P = 0.5000)
# SIDE_TYPE_DEFINITION => EITHER_SIDE_TYPES    (P = 0.5000)
# SIDE_TYPE => side    (P = 1.0000)
# EITHER_SIDE_TYPES => (either [ SIDE ]+ )    (P = 1.0000)
# SIDE => back    (P = 0.2394)
# SIDE => front    (P = 0.3380)
# SIDE => left    (P = 0.2254)
# SIDE => right    (P = 0.1972)
# SETUP_FORALL => (forall VARIABLE_LIST SETUP )    (P = 1.0000)
# SETUP_STATEMENT => SETUP_GAME_CONSERVED    (P = 0.6230)
# SETUP_STATEMENT => SETUP_GAME_OPTIONAL    (P = 0.3770)
# SETUP_GAME_CONSERVED => (game-conserved SUPER_PREDICATE )    (P = 1.0000)
# SUPER_PREDICATE => SUPER_PREDICATE_AND    (P = 0.1914)
# SUPER_PREDICATE => SUPER_PREDICATE_OR    (P = 0.0200)
# SUPER_PREDICATE => SUPER_PREDICATE_NOT    (P = 0.1780)
# SUPER_PREDICATE => SUPER_PREDICATE_EXISTS    (P = 0.0252)
# SUPER_PREDICATE => SUPER_PREDICATE_FORALL    (P = 0.0100)
# SUPER_PREDICATE => FUNCTION_COMPARISON    (P = 0.0490)
# SUPER_PREDICATE => PREDICATE    (P = 0.5265)
# SUPER_PREDICATE_AND => (and [ SUPER_PREDICATE ]+ )    (P = 1.0000)
# SUPER_PREDICATE_OR => (or [ SUPER_PREDICATE ]+ )    (P = 1.0000)
# SUPER_PREDICATE_NOT => (not SUPER_PREDICATE )    (P = 1.0000)
# SUPER_PREDICATE_EXISTS => (exists VARIABLE_LIST SUPER_PREDICATE )    (P = 1.0000)
# SUPER_PREDICATE_FORALL => (forall VARIABLE_LIST SUPER_PREDICATE )    (P = 1.0000)
# FUNCTION_COMPARISON => TWO_ARG_COMPARISON    (P = 0.8880)
# FUNCTION_COMPARISON => MULTIPLE_ARGS_EQUAL_COMPARISON    (P = 0.1120)
# TWO_ARG_COMPARISON => ( BINARY_COMP COMPARISON_ARG COMPARISON_ARG )    (P = 1.0000)
# BINARY_COMP => <=    (P = 0.1733)
# BINARY_COMP => <    (P = 0.1733)
# BINARY_COMP => =    (P = 0.2933)
# BINARY_COMP => >=    (P = 0.2000)
# BINARY_COMP => >    (P = 0.1600)
# COMPARISON_ARG => FUNCTION_EVAL    (P = 0.5983)
# COMPARISON_ARG => COMPARISON_ARG_NUMBER_VALUE    (P = 0.4017)
# FUNCTION_EVAL => FUNCTION_BUILDING_SIZE    (P = 0.0753)
# FUNCTION_EVAL => FUNCTION_DISTANCE    (P = 0.6774)
# FUNCTION_EVAL => FUNCTION_DISTANCE_SIDE_3    (P = 0.0968)
# FUNCTION_EVAL => FUNCTION_DISTANCE_SIDE_4    (P = 0.0645)
# FUNCTION_EVAL => FUNCTION_X_POSITION    (P = 0.0860)
# FUNCTION_BUILDING_SIZE => (building_size PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_OR_FUNCTION_TERM => variable    (P = 1.0000)
# FUNCTION_DISTANCE => (distance PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# FUNCTION_DISTANCE_SIDE_3 => (distance_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_OR_FUNCTION_SIDE_TERM => side_variable    (P = 1.0000)
# FUNCTION_DISTANCE_SIDE_4 => (distance_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM )    (P = 1.0000)
# FUNCTION_X_POSITION => (x_position PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# COMPARISON_ARG_NUMBER_VALUE => NUMBER_PATTERN    (P = 1.0000)
# NUMBER_PATTERN => 0    (P = 0.0118)
# NUMBER_PATTERN => 1    (P = 0.0749)
# NUMBER_PATTERN => 2    (P = 0.0461)
# NUMBER_PATTERN => 3    (P = 0.0548)
# NUMBER_PATTERN => 4    (P = 0.0403)
# NUMBER_PATTERN => 5    (P = 0.0432)
# NUMBER_PATTERN => 6    (P = 0.0432)
# NUMBER_PATTERN => 7    (P = 0.0375)
# NUMBER_PATTERN => 8    (P = 0.0403)
# NUMBER_PATTERN => 9    (P = 0.0346)
# NUMBER_PATTERN => 10    (P = 0.0548)
# NUMBER_PATTERN => 0.5    (P = 0.0128)
# NUMBER_PATTERN => 0.6    (P = 0.0118)
# NUMBER_PATTERN => 0.7    (P = 0.0128)
# NUMBER_PATTERN => 0.2    (P = 0.0118)
# NUMBER_PATTERN => 0.1    (P = 0.0118)
# NUMBER_PATTERN => 0.3    (P = 0.0118)
# NUMBER_PATTERN => 0.8    (P = 0.0118)
# NUMBER_PATTERN => 0.4    (P = 0.0118)
# NUMBER_PATTERN => 0.9    (P = 0.0118)
# NUMBER_PATTERN => 330    (P = 0.0870)
# NUMBER_PATTERN => 300    (P = 0.0024)
# NUMBER_PATTERN => 270    (P = 0.0870)
# NUMBER_PATTERN => 240    (P = 0.0870)
# NUMBER_PATTERN => 210    (P = 0.0870)
# NUMBER_PATTERN => 180    (P = 0.1014)
# NUMBER_PATTERN => 150    (P = 0.0870)
# NUMBER_PATTERN => 120    (P = 0.0870)
# NUMBER_PATTERN => 90    (P = 0.0118)
# NUMBER_PATTERN => 60    (P = 0.0118)
# NUMBER_PATTERN => 30    (P = 0.0158)
# NUMBER_PATTERN => 20    (P = 0.0346)
# NUMBER_PATTERN => 40    (P = 0.0138)
# NUMBER_PATTERN => 50    (P = 0.0138)
# NUMBER_PATTERN => 70    (P = 0.0118)
# NUMBER_PATTERN => -50    (P = 0.0118)
# NUMBER_PATTERN => 80    (P = 0.0118)
# NUMBER_PATTERN => -40    (P = 0.0118)
# NUMBER_PATTERN => -30    (P = 0.0118)
# NUMBER_PATTERN => 100    (P = 0.0158)
# NUMBER_PATTERN => -20    (P = 0.0118)
# NUMBER_PATTERN => -10    (P = 0.0138)
# NUMBER_PATTERN => -9    (P = 0.0118)
# NUMBER_PATTERN => -8    (P = 0.0118)
# NUMBER_PATTERN => -7    (P = 0.0118)
# NUMBER_PATTERN => -6    (P = 0.0118)
# NUMBER_PATTERN => -5    (P = 0.0148)
# NUMBER_PATTERN => -4    (P = 0.0118)
# NUMBER_PATTERN => -3    (P = 0.0148)
# NUMBER_PATTERN => -2    (P = 0.0118)
# NUMBER_PATTERN => -1    (P = 0.0118)
# NUMBER_PATTERN => 11    (P = 0.0346)
# NUMBER_PATTERN => 12    (P = 0.0375)
# NUMBER_PATTERN => 13    (P = 0.0346)
# NUMBER_PATTERN => 14    (P = 0.0346)
# NUMBER_PATTERN => 15    (P = 0.0375)
# NUMBER_PATTERN => 16    (P = 0.0375)
# NUMBER_PATTERN => 17    (P = 0.0346)
# NUMBER_PATTERN => 18    (P = 0.0375)
# NUMBER_PATTERN => 19    (P = 0.0346)
# NUMBER_PATTERN => 21    (P = 0.0346)
# NUMBER_PATTERN => 22    (P = 0.0346)
# NUMBER_PATTERN => 23    (P = 0.0346)
# NUMBER_PATTERN => 24    (P = 0.0346)
# NUMBER_PATTERN => 25    (P = 0.0346)
# NUMBER_PATTERN => -25    (P = 0.0118)
# NUMBER_PATTERN => -24    (P = 0.0118)
# NUMBER_PATTERN => -23    (P = 0.0118)
# NUMBER_PATTERN => -22    (P = 0.0118)
# NUMBER_PATTERN => -21    (P = 0.0118)
# NUMBER_PATTERN => -19    (P = 0.0118)
# NUMBER_PATTERN => -18    (P = 0.0118)
# NUMBER_PATTERN => -17    (P = 0.0118)
# NUMBER_PATTERN => -16    (P = 0.0118)
# NUMBER_PATTERN => -15    (P = 0.0118)
# NUMBER_PATTERN => -14    (P = 0.0118)
# NUMBER_PATTERN => -13    (P = 0.0118)
# NUMBER_PATTERN => -12    (P = 0.0118)
# NUMBER_PATTERN => -11    (P = 0.0118)
# MULTIPLE_ARGS_EQUAL_COMPARISON => (= [ COMPARISON_ARG ]+ )    (P = 1.0000)
# PREDICATE => PREDICATE_ABOVE    (P = 0.0112)
# PREDICATE => PREDICATE_ADJACENT    (P = 0.0595)
# PREDICATE => PREDICATE_ADJACENT_SIDE_3    (P = 0.0165)
# PREDICATE => PREDICATE_ADJACENT_SIDE_4    (P = 0.0093)
# PREDICATE => PREDICATE_AGENT_CROUCHES    (P = 0.0093)
# PREDICATE => PREDICATE_AGENT_HOLDS    (P = 0.2241)
# PREDICATE => PREDICATE_BETWEEN    (P = 0.0126)
# PREDICATE => PREDICATE_BROKEN    (P = 0.0093)
# PREDICATE => PREDICATE_EQUAL_X_POSITION    (P = 0.0093)
# PREDICATE => PREDICATE_EQUAL_Z_POSITION    (P = 0.0112)
# PREDICATE => PREDICATE_FACES    (P = 0.0119)
# PREDICATE => PREDICATE_GAME_OVER    (P = 0.0106)
# PREDICATE => PREDICATE_GAME_START    (P = 0.0099)
# PREDICATE => PREDICATE_IN    (P = 0.0879)
# PREDICATE => PREDICATE_IN_MOTION    (P = 0.2161)
# PREDICATE => PREDICATE_IS_SETUP_OBJECT    (P = 0.0165)
# PREDICATE => PREDICATE_OBJECT_ORIENTATION    (P = 0.0172)
# PREDICATE => PREDICATE_ON    (P = 0.1190)
# PREDICATE => PREDICATE_OPEN    (P = 0.0099)
# PREDICATE => PREDICATE_OPPOSITE    (P = 0.0106)
# PREDICATE => PREDICATE_RUG_COLOR_UNDER    (P = 0.0152)
# PREDICATE => PREDICATE_SAME_COLOR    (P = 0.0231)
# PREDICATE => PREDICATE_SAME_OBJECT    (P = 0.0126)
# PREDICATE => PREDICATE_SAME_TYPE    (P = 0.0172)
# PREDICATE => PREDICATE_TOGGLED_ON    (P = 0.0106)
# PREDICATE => PREDICATE_TOUCH    (P = 0.0397)
# PREDICATE_ABOVE => (above PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_ADJACENT => (adjacent PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_ADJACENT_SIDE_3 => (adjacent_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_ADJACENT_SIDE_4 => (adjacent_side PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_SIDE_TERM )    (P = 1.0000)
# PREDICATE_AGENT_CROUCHES => (agent_crouches EMPTY_CLOSURE )    (P = 1.0000)
# PREDICATE_AGENT_HOLDS => (agent_holds PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_BETWEEN => (between PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_BROKEN => (broken PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_EQUAL_X_POSITION => (equal_x_position PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_EQUAL_Z_POSITION => (equal_z_position PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_FACES => (faces PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_GAME_OVER => (game_over EMPTY_CLOSURE )    (P = 1.0000)
# PREDICATE_GAME_START => (game_start EMPTY_CLOSURE )    (P = 1.0000)
# PREDICATE_IN => (in PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_IN_MOTION => (in_motion PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_IS_SETUP_OBJECT => (is_setup_object PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_OBJECT_ORIENTATION => (object_orientation PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_ORIENTATION_TERM )    (P = 1.0000)
# PREDICATE_OR_FUNCTION_ORIENTATION_TERM => orientation_variable    (P = 1.0000)
# PREDICATE_ON => (on PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_OPEN => (open PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_OPPOSITE => (opposite PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_RUG_COLOR_UNDER => (rug_color_under PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_COLOR_TERM )    (P = 1.0000)
# PREDICATE_OR_FUNCTION_COLOR_TERM => color_variable    (P = 1.0000)
# PREDICATE_SAME_COLOR => (same_color PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_COLOR_TERM )    (P = 0.6809)
# PREDICATE_SAME_COLOR => (same_color PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 0.3191)
# PREDICATE_SAME_OBJECT => (same_object PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_SAME_TYPE => (same_type PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TYPE_TERM )    (P = 1.0000)
# PREDICATE_OR_FUNCTION_TYPE_TERM => variable    (P = 1.0000)
# PREDICATE_TOGGLED_ON => (toggled_on PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# PREDICATE_TOUCH => (touch PREDICATE_OR_FUNCTION_TERM PREDICATE_OR_FUNCTION_TERM )    (P = 1.0000)
# SETUP_GAME_OPTIONAL => (game-optional SUPER_PREDICATE )    (P = 1.0000)
# CONSTRAINTS_DEF => (:constraints PREFERENCES )    (P = 1.0000)
# PREFERENCES => (and [ PREF_DEF ]+ )    (P = 1.0000)
# PREF_DEF => PREFERENCE    (P = 0.7092)
# PREF_DEF => PREF_FORALL    (P = 0.2908)
# PREFERENCE => (preference PREFERENCE_NAME PREF_BODY )    (P = 1.0000)
# PREFERENCE_NAME => NAME    (P = 1.0000)
# NAME => /[A-Za-z][A-Za-z0-9_]*/    (P = 1.0000)
# PREF_BODY => PREF_BODY_EXISTS    (P = 0.8496)
# PREF_BODY => THEN    (P = 0.0973)
# PREF_BODY => AT_END    (P = 0.0531)
# PREF_BODY_EXISTS => (exists VARIABLE_LIST THEN )    (P = 0.7843)
# PREF_BODY_EXISTS => (exists VARIABLE_LIST AT_END )    (P = 0.2157)
# THEN => (then [ SEQ_FUNC ]+ )    (P = 1.0000)
# SEQ_FUNC => ONCE    (P = 0.6089)
# SEQ_FUNC => ONCE_MEASURE    (P = 0.0242)
# SEQ_FUNC => HOLD    (P = 0.2793)
# SEQ_FUNC => WHILE_HOLD    (P = 0.0875)
# ONCE => (once  SUPER_PREDICATE )    (P = 1.0000)
# ONCE_MEASURE => (once-measure SUPER_PREDICATE FUNCTION_EVAL )    (P = 1.0000)
# HOLD => (hold SUPER_PREDICATE )    (P = 1.0000)
# WHILE_HOLD => (hold-while SUPER_PREDICATE [ SUPER_PREDICATE ]+ )    (P = 1.0000)
# AT_END => (at-end SUPER_PREDICATE )    (P = 1.0000)
# PREF_FORALL => (forall VARIABLE_LIST PREF_FORALL_PREFS )    (P = 1.0000)
# PREF_FORALL_PREFS => (and [ PREFERENCE ]+ )    (P = 1.0000)
# TERMINAL_DEF => (:terminal TERMINAL )    (P = 0.4592)
# TERMINAL_DEF => $\epsilon$    (P = 0.5408)
# TERMINAL => TERMINAL_AND    (P = 0.1040)
# TERMINAL => TERMINAL_OR    (P = 0.2000)
# TERMINAL => TERMINAL_NOT    (P = 0.0960)
# TERMINAL => TERMINAL_COMP    (P = 0.6000)
# TERMINAL_AND => (and [ TERMINAL ]+ )    (P = 1.0000)
# TERMINAL_OR => (or [ TERMINAL ]+ )    (P = 1.0000)
# TERMINAL_NOT => (not TERMINAL )    (P = 1.0000)
# TERMINAL_COMP => TERMINAL_TIME_COMP    (P = 0.1818)
# TERMINAL_COMP => TERMINAL_SCORE_COMP    (P = 0.2222)
# TERMINAL_COMP => TERMINAL_PREF_COUNT_COMP    (P = 0.5960)
# TERMINAL_TIME_COMP => ( BINARY_COMP TOTAL_TIME TIME_NUMBER_VALUE )    (P = 1.0000)
# TOTAL_TIME => (total-time)    (P = 1.0000)
# TIME_NUMBER_VALUE => NUMBER_PATTERN    (P = 1.0000)
# TERMINAL_SCORE_COMP => ( BINARY_COMP TOTAL_SCORE SCORE_NUMBER_VALUE )    (P = 1.0000)
# TOTAL_SCORE => (total-score)    (P = 1.0000)
# SCORE_NUMBER_VALUE => NUMBER_PATTERN    (P = 1.0000)
# TERMINAL_PREF_COUNT_COMP => ( BINARY_COMP SCORING_EXPR_OR_NUMBER PREF_COUNT_NUMBER_VALUE )    (P = 1.0000)
# SCORING_EXPR_OR_NUMBER => SCORING_EXPR    (P = 0.7263)
# SCORING_EXPR_OR_NUMBER => SCORING_NUMBER_VALUE    (P = 0.2737)
# SCORING_EXPR => SCORING_EXTERNAL_MAXIMIZE    (P = 0.0404)
# SCORING_EXPR => SCORING_EXTERNAL_MINIMIZE    (P = 0.0187)
# SCORING_EXPR => SCORING_MULTI_EXPR    (P = 0.3390)
# SCORING_EXPR => SCORING_BINARY_EXPR    (P = 0.0202)
# SCORING_EXPR => SCORING_NEG_EXPR    (P = 0.0404)
# SCORING_EXPR => PREFERENCE_EVAL    (P = 0.4992)
# SCORING_EXPR => SCORING_COMPARISON    (P = 0.0420)
# SCORING_EXTERNAL_MAXIMIZE => (external-forall-maximize SCORING_EXPR )    (P = 1.0000)
# SCORING_EXTERNAL_MINIMIZE => (external-forall-minimize SCORING_EXPR )    (P = 1.0000)
# SCORING_MULTI_EXPR => ( MULTI_OP [ SCORING_EXPR_OR_NUMBER ]+ )    (P = 1.0000)
# MULTI_OP => +    (P = 0.3000)
# MULTI_OP => *    (P = 0.7000)
# SCORING_BINARY_EXPR => ( BINARY_OP SCORING_EXPR_OR_NUMBER SCORING_EXPR_OR_NUMBER )    (P = 1.0000)
# BINARY_OP => -    (P = 0.4800)
# BINARY_OP => /    (P = 0.5200)
# SCORING_NEG_EXPR => (- SCORING_EXPR_OR_NUMBER )    (P = 1.0000)
# PREFERENCE_EVAL => COUNT    (P = 0.4305)
# PREFERENCE_EVAL => COUNT_OVERLAPPING    (P = 0.0331)
# PREFERENCE_EVAL => COUNT_ONCE    (P = 0.0795)
# PREFERENCE_EVAL => COUNT_ONCE_PER_OBJECTS    (P = 0.2185)
# PREFERENCE_EVAL => COUNT_LONGEST    (P = 0.0265)
# PREFERENCE_EVAL => COUNT_SHORTEST    (P = 0.0265)
# PREFERENCE_EVAL => COUNT_TOTAL    (P = 0.0265)
# PREFERENCE_EVAL => COUNT_INCREASING_MEASURE    (P = 0.0265)
# PREFERENCE_EVAL => COUNT_UNIQUE_POSITIONS    (P = 0.0287)
# PREFERENCE_EVAL => COUNT_SAME_POSITIONS    (P = 0.0287)
# PREFERENCE_EVAL => COUNT_ONCE_PER_EXTERNAL_OBJECTS    (P = 0.0464)
# PREFERENCE_EVAL => COUNT_MEASURE    (P = 0.0287)
# COUNT => (count PREF_NAME_AND_TYPES )    (P = 1.0000)
# PREF_NAME_AND_TYPES => PREFERENCE_NAME [ PREF_OBJECT_TYPE ]*    (P = 1.0000)
# PREF_OBJECT_TYPE => : COLOR    (P = 0.2821)
# PREF_OBJECT_TYPE => : OBJECT_NAME    (P = 0.0821)
# PREF_OBJECT_TYPE => : OBJECT_TYPE    (P = 0.6359)
# OBJECT_NAME => agent    (P = 0.2043)
# OBJECT_NAME => bed    (P = 0.1113)
# OBJECT_NAME => desk    (P = 0.1279)
# OBJECT_NAME => door    (P = 0.0449)
# OBJECT_NAME => floor    (P = 0.0598)
# OBJECT_NAME => main_light_switch    (P = 0.0216)
# OBJECT_NAME => mirror    (P = 0.0199)
# OBJECT_NAME => room_center    (P = 0.0731)
# OBJECT_NAME => rug    (P = 0.0797)
# OBJECT_NAME => side_table    (P = 0.0282)
# OBJECT_NAME => bottom_drawer    (P = 0.0199)
# OBJECT_NAME => bottom_shelf    (P = 0.0216)
# OBJECT_NAME => east_sliding_door    (P = 0.0216)
# OBJECT_NAME => east_wall    (P = 0.0199)
# OBJECT_NAME => north_wall    (P = 0.0216)
# OBJECT_NAME => south_wall    (P = 0.0233)
# OBJECT_NAME => top_drawer    (P = 0.0282)
# OBJECT_NAME => top_shelf    (P = 0.0282)
# OBJECT_NAME => west_sliding_door    (P = 0.0199)
# OBJECT_NAME => west_wall    (P = 0.0249)
# COUNT_OVERLAPPING => (count-overlapping PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_ONCE => (count-once PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_ONCE_PER_OBJECTS => (count-once-per-objects PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_LONGEST => (count-longest PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_SHORTEST => (count-shortest PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_TOTAL => (count-total PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_INCREASING_MEASURE => (count-increasing-measure PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_UNIQUE_POSITIONS => (count-unique-positions PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_SAME_POSITIONS => (count-same-positions PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_ONCE_PER_EXTERNAL_OBJECTS => (count-once-per-external-objects PREF_NAME_AND_TYPES )    (P = 1.0000)
# COUNT_MEASURE => (count-measure PREF_NAME_AND_TYPES )    (P = 1.0000)
# SCORING_COMPARISON => SCORING_COMP    (P = 0.6923)
# SCORING_COMPARISON => SCORING_EQUALS_COMP    (P = 0.3077)
# SCORING_COMP => ( BINARY_COMP SCORING_EXPR_OR_NUMBER SCORING_EXPR_OR_NUMBER )    (P = 1.0000)
# SCORING_EQUALS_COMP => (= [ SCORING_EXPR_OR_NUMBER ]+ )    (P = 1.0000)
# SCORING_NUMBER_VALUE => NUMBER_PATTERN    (P = 1.0000)
# PREF_COUNT_NUMBER_VALUE => NUMBER_PATTERN    (P = 1.0000)
# SCORING_DEF => (:scoring SCORING )    (P = 1.0000)
# SCORING => SCORING_EXPR    (P = 1.0000)
# ## Token rule expansions

# %% [markdown]
# ## Manual edits to make
# * Change the way VARIABLE_LIST is written to expan to some generic list of variable definitions, which expands to each of the variable type defs

# %%
sampler.rules['game_def']

# %%
game_texts = list(load_games_from_file('../dsl/interactive-beta.pddl'))

# %%
sampler.rules['predicate_or_function_term']['term']['token_posterior']
